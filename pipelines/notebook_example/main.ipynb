# %% [markdown]
# # Fast-Flow Notebook-Beispiel
#
# Diese Pipeline läuft als **Notebook** (main.ipynb).
# - Zellen mit `fastflow` in den Cell-Metadaten unterstützen **Retry** (retries, delay_seconds).
# - Logs werden pro Zelle in der Run-Detail-Ansicht angezeigt.

# %%
import sys
print('Python:', sys.version)
print('Notebook-Pipeline gestartet.')

# %%
# Einfache Berechnung
x = 1 + 2
print(f'1 + 2 = {x}')

# %%
raise Exception('Test-Fehler')

# %%
# Abschluss
print('Notebook-Pipeline erfolgreich beendet.')
